# %%
import json

from tqdm import tqdm
def evaluation_single_choice(data_path):
        
    base = [json.loads(q) for q in open(data_path, "r")]
    correct=0
    incorrect=0
    for answers in tqdm(base):
        gt=answers['ground_truth']
        answer=answers['text']
        if gt.lower()==answer.lower():
            correct=correct+1
        else:
            incorrect=incorrect+1
    print('correct:',correct)
    print('incorrect:',incorrect)
    print('Total:',correct+incorrect)
    print('Acc:',(correct/(correct+incorrect)))


'''
evaluation_single_choice("/mnt/public/vila-1.5/our_results/multiview/vila_train_sisv_pretrain_35w_multi.jsonl")
evaluation_single_choice("/mnt/public/vila-1.5/our_results/multiview/2vila_train_sisv_pretrain_35w_multi.jsonl")


evaluation_single_choice("/mnt/public/vila-1.5/our_results/multiview/vila_train_sisv_pretrain_att_35w_clean_multi copy.jsonl")
evaluation_single_choice("/mnt/public/vila-1.5/our_results/multiview/1vila_train_sisv_pretrain_att_35w_clean_multiV2.jsonl")
evaluation_single_choice("/mnt/public/vila-1.5/our_results/multiview/2vila_train_sisv_pretrain_att_35w_clean_multiV2.jsonl")

evaluation_single_choice("/mnt/public/vila-1.5/our_results/multiviewpair/vila_train_sisv_pretrain_att_35w_clean_multiV2.jsonl")

evaluation_single_choice("/mnt/public/vila-1.5/our_results/multiview_only_position/vila_train_all_sisv_pretrain_att_186w_clean.jsonl")

evaluation_single_choice("/mnt/public/vila-1.5/our_results/multiview_only_position/vila_train_all_sisv_clean_8b.jsonl")

'''
evaluation_single_choice("/data3/zhangxin/wuwen/vila-1.5/rebuttal_results/multi/position/vila_train_all_sisv_pretrain_att_35w_clean_8bV4.jsonl")

evaluation_single_choice("/data3/zhangxin/wuwen/vila-1.5/rebuttal_results/multi/position/Llama-3-VILA1.5-8B.jsonl")
# Out:
# 100%|██████████| 1000/1000 [00:00<00:00, 653420.16it/s]
# correct: 415
# incorrect: 585
# Total: 1000
# Acc: 0.415
# 100%|██████████| 1000/1000 [00:00<00:00, 1650650.92it/s]
# correct: 220
# incorrect: 780
# Total: 1000
# Acc: 0.22

# %%
import sklearn.metrics as metrics
import json
import   re
def compute_accuracy_regression(pred_list, true_list):
    mse = metrics.mean_squared_error(true_list, pred_list)
    mae = metrics.mean_absolute_error(true_list, pred_list)
    r2 = metrics.r2_score(true_list, pred_list)
    
    rmse = metrics.mean_squared_error(true_list, pred_list, squared=False)
    return mse, mae, r2,rmse

def evaluation_metrics(data_path):
    data = []
    with open(data_path, 'r') as file:
        for line in file:
            data.append(json.loads(line))
            




    pred_list = [] 
    true_list = [] 

    for item in data:
        sdg_str = item['text']
        #print(coordinates_str)
        # 去除字符串中的括号并按逗号分割，然后转换为浮点数
        #只匹配text中的经纬度
        match = re.search(r"(\d+\.\d+)", sdg_str)
        if match:
            
            rating = float(match.group(0))
            pred_list.append(rating)  # 将元组添加到列表中
        
            sdg_str = str(item['ground_truth'])
            match = re.search(r"(\d+\.\d+)", sdg_str)
            if match:
                
                rating = float(match.group(0))
                true_list.append(rating)  # 将元组添加到列表中
            
    
    mse, mae, r2,rmse = compute_accuracy_regression(pred_list, true_list)
    import matplotlib.pyplot as plt
    print('mse:',mse)
    print('mae:',mae)
    print('r2:',r2)
    print('rmse:',rmse)
    
    print("---------------")
'''
evaluation_metrics("/mnt/public/vila-1.5/our_results/multiviewincome/vila_train_sisv_pretrain_35w_multi.jsonl")

evaluation_metrics("/mnt/public/vila-1.5/our_results/multiviewincome/vila_train_sisv_pretrain_att_35w_clean_multiV2.jsonl")
evaluation_metrics("/mnt/public/vila-1.5/our_results/multiviewdepression/vila_train_sisv_pretrain_35w_multi.jsonl")
evaluation_metrics("/mnt/public/vila-1.5/our_results/multiviewdepression/vila_train_sisv_pretrain_att_35w_clean_multiV2.jsonl")
evaluation_metrics("/mnt/public/vila-1.5/our_results/multiviewincome/vila_train_all_sisv_pretrain_att_186w_clean.jsonl")

evaluation_metrics("/mnt/public/vila-1.5/our_results/multiviewincome2/vila_train_all_sisv_pretrain_att_186w_clean.jsonl")

evaluation_metrics("/mnt/public/vila-1.5/our_results/multiviewincome2/vila_train_all_sisv_pretrain_att_186w_clean_3b.jsonl")

evaluation_metrics("/mnt/public/vila-1.5/paper_results/sv/PlacePulse_wealthier/vila_train_all_sisv_pretrain_att_186w_clean.jsonl")
evaluation_metrics("/mnt/public/vila-1.5/paper_results/multi/pop/vila_train_all_sisv_pretrain_att_186w_clean.jsonl")
evaluation_metrics("/mnt/public/vila-1.5/paper_results/multi/income/vila_train_all_sisv_pretrain_att_186w_clean.jsonl")
#evaluation_metrics("/mnt/public/vila-1.5/paper_results/sv/PlacePulse_more_beautiful/vila_train_all_sisv_pretrain_att_186w_clean.jsonl")
evaluation_metrics("/mnt/public/vila-1.5/paper_results/multi/poverty_ratio/vila_train_all_sisv_pretrain_att_186w_clean.jsonl")
evaluation_metrics("/mnt/public/vila-1.5/paper_results/multi/depression/vila_train_all_sisv_pretrain_att_186w_clean.jsonl")


evaluation_metrics("/mnt/public/vila-1.5/paper_results/multi/pop/vila_train_all_sisv_clean_8b.jsonl")
evaluation_metrics("/mnt/public/vila-1.5/paper_results/multi/income/vila_train_all_sisv_clean_8b.jsonl")
#evaluation_metrics("/mnt/public/vila-1.5/paper_results/sv/PlacePulse_more_beautiful/vila_train_all_sisv_pretrain_att_186w_clean.jsonl")
evaluation_metrics("/mnt/public/vila-1.5/paper_results/multi/poverty_ratio/vila_train_all_sisv_clean_8b.jsonl")
evaluation_metrics("/mnt/public/vila-1.5/paper_results/multi/depression/vila_train_all_sisv_clean_8b.jsonl")

evaluation_metrics("/mnt/public/vila-1.5/paper_results/multi/pop/vila_train_all_sisv_clean_8b.jsonl")
evaluation_metrics("/mnt/public/vila-1.5/paper_results/multi/income/vila_train_all_sisv_clean_8b.jsonl")
#evaluation_metrics("/mnt/public/vila-1.5/paper_results/sv/PlacePulse_more_beautiful/vila_train_all_sisv_pretrain_att_186w_clean.jsonl")
evaluation_metrics("/mnt/public/vila-1.5/paper_results/multi/poverty_ratio/vila_train_all_sisv_clean_8b.jsonl")
evaluation_metrics("/mnt/public/vila-1.5/paper_results/multi/depression/vila_train_all_sisv_clean_8b.jsonl")
'''
# Out:
# '\nevaluation_metrics("/mnt/public/vila-1.5/our_results/multiviewincome/vila_train_sisv_pretrain_35w_multi.jsonl")\n\nevaluation_metrics("/mnt/public/vila-1.5/our_results/multiviewincome/vila_train_sisv_pretrain_att_35w_clean_multiV2.jsonl")\nevaluation_metrics("/mnt/public/vila-1.5/our_results/multiviewdepression/vila_train_sisv_pretrain_35w_multi.jsonl")\nevaluation_metrics("/mnt/public/vila-1.5/our_results/multiviewdepression/vila_train_sisv_pretrain_att_35w_clean_multiV2.jsonl")\nevaluation_metrics("/mnt/public/vila-1.5/our_results/multiviewincome/vila_train_all_sisv_pretrain_att_186w_clean.jsonl")\n\nevaluation_metrics("/mnt/public/vila-1.5/our_results/multiviewincome2/vila_train_all_sisv_pretrain_att_186w_clean.jsonl")\n\nevaluation_metrics("/mnt/public/vila-1.5/our_results/multiviewincome2/vila_train_all_sisv_pretrain_att_186w_clean_3b.jsonl")\n\nevaluation_metrics("/mnt/public/vila-1.5/paper_results/sv/PlacePulse_wealthier/vila_train_all_sisv_pretrain_att_186w_clean.jsonl")\n
# ...

# %%
#scene classifcatrion
import json

from tqdm import tqdm
def evaluation_metrics(data_path):
        
    base = [json.loads(q) for q in open(data_path, "r")]
    correct=0
    incorrect=0
    for answers in tqdm(base):
        gt=answers['ground_truth']
        answer=answers['text']
        if gt==answer:
                correct=correct+1
        else:
                incorrect=incorrect+1
        # else:
        #     continue
    print('correct:',correct)
    print('incorrect:',incorrect)
    print('Total:',correct+incorrect)
    print('Acc:',(correct/(correct+incorrect)))
'''
evaluation_metrics("/mnt/public/vila-1.5/our_results/multiview_only_position/vila_train_sisv_pretrain_att_35w_clean_multi_only_position.jsonl")
evaluation_metrics("/mnt/public/vila-1.5/our_results/multiview_only_position/vila_train_sisv_pretrain_35w_clean_multi_only_position.jsonl")
evaluation_metrics("/mnt/public/vila-1.5/paper_results/multi/position/vila_train_all_sisv_pretrain_att_186w_clean.jsonl")
evaluation_metrics("/mnt/public/vila-1.5/paper_results/multi/position/vila_train_all_sisv_clean_8b.jsonl")
evaluation_metrics("/mnt/public/vila-1.5/paper_results/multi/position/vila_train_all_sisv_pretrain_186w_clean_only_si.jsonl")


evaluation_metrics("/mnt/public/vila-1.5/paper_results/multi/position/vila_train_all_sisv_clean_8b.jsonl")
evaluation_metrics("/mnt/public/vila-1.5/paper_results/multi/position/vila_train_all_sisv_pretrain_186w_clean_only_si.jsonl")

evaluation_metrics("/mnt/public/vila-1.5/paper_results/multi/position/vila_train_all_sisv_pretrain_186w_clean_only_sv.jsonl")
evaluation_metrics("/mnt/public/vila-1.5/paper_results/multi/position/vila_train_all_sisv_pretrain_186w_clean.jsonl")

evaluation_single_choice("/mnt/public/vila-1.5/paper_results/multi/position/vila_train_all_sisv_att_186w_clean_13bV2.jsonl")
'''
evaluation_single_choice("/data3/zhangxin/wuwen/vila-1.5/rebuttal_results/multi/position/vila_train_all_sisv_pretrain_att_35w_clean_8b.jsonl")
evaluation_single_choice("/data3/zhangxin/wuwen/vila-1.5/rebuttal_results/multi/position/vila_train_all_sisv_pretrain_att_100w_clean_8b.jsonl")

evaluation_metrics("/data3/zhangxin/wuwen/vila-1.5/rebuttal_results/multi/position/vila_train_all_sisv_pretrain_att_186w_clean_8B_llava_instruct150k.jsonl")

evaluation_single_choice("/data3/zhangxin/wuwen/vila-1.5/rebuttal_results/multi/position/vila_train_all_sisv_pretrain_att_186w_clean_8B_llava_instruct150k.jsonl")


evaluation_metrics("/data3/zhangxin/wuwen/vila-1.5/last_results/multi/position/vila_train_all_sisv_pretrain_att_sharegpt4v_186w_clean_8B_llava_instruct150k.jsonl")
# Out:
# 100%|██████████| 1000/1000 [00:00<00:00, 2832075.62it/s]
# correct: 264
# incorrect: 736
# Total: 1000
# Acc: 0.264
# 100%|██████████| 1000/1000 [00:00<00:00, 1133595.68it/s]
# correct: 418
# incorrect: 582
# Total: 1000
# Acc: 0.418
# 100%|██████████| 1000/1000 [00:00<00:00, 1314416.80it/s]
# correct: 430
# incorrect: 570
# Total: 1000
# Acc: 0.43
# 100%|██████████| 1000/1000 [00:00<00:00, 1132371.49it/s]
# correct: 430
# incorrect: 570
# Total: 1000
# Acc: 0.43
# 100%|██████████| 1000/1000 [00:00<00:00, 1312360.45it/s]
# correct: 423
# incorrect: 577
# Total: 1000
# Acc: 0.423

# %%
import os
import ast
import json
import numpy as np
import pandas as pd
from sklearn.metrics import r2_score

task_list = [
    "Socioeconomic_depression_rate",
    "Socioeconomic_total_population",
    "Socioeconomic_median_income",
    "Socioeconomic_poverty_ratio",
    "Socioeconomic_no_health_insurance_ratio",
    "Image_Retrieval_pairing",
    "Image_Retrieval_positioning"
]

def compare(test_label_list, test_pred_list, margin=0):
    correct = 0
    length = len(test_label_list)
    for label, pred in zip(test_label_list, test_pred_list):
        if abs(label - pred) <= margin:
            correct += 1
    acc = correct / length if length > 0 else 0
    return acc



def evaluation_metrics(test_pred_jsonl):

    results = {}
    with open(test_pred_jsonl, "r") as f:
        test_pred_data = f.readlines()

    test_pred_list = []
    test_label_list = []
    # Calculate accuracy for Socioeconomic Prediction tasks
    
    
    
    for i in range(len(test_pred_data)):
        test_pred = ast.literal_eval(test_pred_data[i])["text"]
        try:
            test_pred_list.append(np.floor(float(test_pred)))
            test_label = ast.literal_eval(test_pred_data[i])["ground_truth"]
            test_label_list.append(np.floor(float(test_label)))
        except:
            continue

    acc = compare(test_label_list, test_pred_list, margin=2)
    print(acc)
    
'''
print("income")



evaluation_metrics("/data3/zhangxin/wuwen/vila-1.5/paper_results/multi/pop/vila_train_all_sisv_att_186w_clean_13bV2.jsonl")

evaluation_metrics("/data3/zhangxin/wuwen/vila-1.5/paper_results/multi/income/vila_train_all_sisv_att_186w_clean_13bV2.jsonl")
evaluation_metrics("/data3/zhangxin/wuwen/vila-1.5/paper_results/multi/poverty_ratio/vila_train_all_sisv_att_186w_clean_13bV2.jsonl")
evaluation_metrics("/data3/zhangxin/wuwen/vila-1.5/paper_results/multi/depression/vila_train_all_sisv_att_186w_clean_13bV2.jsonl")

print("income")

#evaluation_metrics("/data3/zhangxin/wuwen/vila-1.5/our_results/multiviewdepression/vila_train_sisv_pretrain_35w_multi.jsonl")

#evaluation_metrics("/data3/zhangxin/wuwen/vila-1.5/our_results/multiviewdepression/vila_train_sisv_pretrain_att_35w_clean_multiV2.jsonl")


evaluation_metrics("/data3/zhangxin/wuwen/vila-1.5/paper_results/sv/PlacePulse_more_depressing/vila_train_all_sisv_pretrain_att_186w_clean.jsonl")
evaluation_metrics("/data3/zhangxin/wuwen/vila-1.5/paper_results/sv/PlacePulse_more_beautiful/vila_train_all_sisv_pretrain_att_186w_clean.jsonl")
evaluation_metrics("/data3/zhangxin/wuwen/vila-1.5/paper_results/sv/PlacePulse_more_depressing/vila_train_all_sisv_pretrain_att_186w_clean_3b.jsonl")
evaluation_metrics("/data3/zhangxin/wuwen/vila-1.5/paper_results/sv/PlacePulse_more_beautiful/vila_train_all_sisv_pretrain_att_186w_clean_3b.jsonl")
evaluation_metrics("/data3/zhangxin/wuwen/vila-1.5/paper_results/sv/PlacePulse_wealthier/vila_train_all_sisv_pretrain_att_186w_clean_3b.jsonl")

#evaluation_metrics("/data3/zhangxin/wuwen/vila-1.5/1113_results/pop/vila_train_all_sisv_pretrain_att_186w_clean.jsonl")


evaluation_metrics("/data3/zhangxin/wuwen/vila-1.5/rebuttal_results/pop/vila_train_all_sisv_pretrain_att_100w_clean_8b.jsonl")
evaluation_metrics("/data3/zhangxin/wuwen/vila-1.5/rebuttal_results/nightlight/vila_train_all_sisv_pretrain_att_100w_clean_8b.jsonl")
evaluation_metrics("/data3/zhangxin/wuwen/vila-1.5/rebuttal_results/multi/pop/vila_train_all_sisv_pretrain_att_186w_clean_8B_multi6.jsonl")


'''
print("pop")
evaluation_metrics("/data3/zhangxin/wuwen/vila-1.5/rebuttal_results/multi/pop/vila_train_all_sisv_pretrain_att_35w_clean_8bV4.jsonl")
evaluation_metrics("/data3/zhangxin/wuwen/vila-1.5/rebuttal_results/multi/pop/vila_train_all_sisv_pretrain_att_100w_clean_8b.jsonl")
print("income")
evaluation_metrics("/data3/zhangxin/wuwen/vila-1.5/rebuttal_results/multi/income/vila_train_all_sisv_pretrain_att_35w_clean_8bV4.jsonl")
evaluation_metrics("/data3/zhangxin/wuwen/vila-1.5/rebuttal_results/multi/income/vila_train_all_sisv_pretrain_att_100w_clean_8b.jsonl")

print("poverty_ratio")
evaluation_metrics("/data3/zhangxin/wuwen/vila-1.5/rebuttal_results/multi/poverty_ratio/vila_train_all_sisv_pretrain_att_35w_clean_8bV4.jsonl")
evaluation_metrics("/data3/zhangxin/wuwen/vila-1.5/rebuttal_results/multi/poverty_ratio/vila_train_all_sisv_pretrain_att_100w_clean_8b.jsonl")
print("depression")
evaluation_metrics("/data3/zhangxin/wuwen/vila-1.5/rebuttal_results/multi/depression/vila_train_all_sisv_pretrain_att_35w_clean_8bV4.jsonl")
evaluation_metrics("/data3/zhangxin/wuwen/vila-1.5/rebuttal_results/multi/depression/vila_train_all_sisv_pretrain_att_100w_clean_8b.jsonl")


print("si")
evaluation_metrics("/data3/zhangxin/wuwen/vila-1.5/rebuttal_results/nightlight/vila_train_all_sisv_pretrain_att_35w_clean_8bV4.jsonl")
evaluation_metrics("/data3/zhangxin/wuwen/vila-1.5/rebuttal_results/nightlight/vila_train_all_sisv_pretrain_att_100w_clean_8b.jsonl")
evaluation_metrics("/data3/zhangxin/wuwen/vila-1.5/rebuttal_results/pop/vila_train_all_sisv_pretrain_att_35w_clean_8bV4.jsonl")
evaluation_metrics("/data3/zhangxin/wuwen/vila-1.5/rebuttal_results/pop/vila_train_all_sisv_pretrain_att_100w_clean_8b.jsonl")
'''
evaluation_metrics("/data3/zhangxin/wuwen/vila-1.5/rebuttal_results/pop/vila_train_all_sisv_pretrain_att_35w_clean_8bV4.jsonl")
evaluation_metrics("/data3/zhangxin/wuwen/vila-1.5/rebuttal_results/pop/vila_train_all_sisv_pretrain_att_35w_clean_8bV3.jsonl")
evaluation_metrics("/data3/zhangxin/wuwen/vila-1.5/rebuttal_results/nightlight/vila_train_all_sisv_pretrain_att_35w_clean_8bV4.jsonl")
'''
print("gini")

evaluation_metrics("/data3/zhangxin/wuwen/vila-1.5/gini_results/multi/Tract_gini_coefficient/vila_train_all_sisv_pretrain_att_186w_clean_8B.jsonl")


evaluation_metrics("/data3/zhangxin/wuwen/vila-1.5/gini_results/multi/Tract_white_black_income_ratio/vila_train_all_sisv_pretrain_att_186w_clean_8B.jsonl")



evaluation_metrics("/data3/zhangxin/wuwen/vila-1.5/citybench/pop/vila_train_all_sisv_pretrain_att_186w_clean.jsonl")
# Out:
# pop
# 0.574
# 0.576
# income
# 0.805
# 0.809
# poverty_ratio
# 0.715
# 0.705
# depression
# 0.759
# 0.723
# si
# 0.77
# 0.78
# 0.907
# 0.906
# gini
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /data3/zhangxin/wuwen/vila-1.5/our_eval/test_multiview.ipynb 单元格 4 line 1
#     <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a224c4d32227d/data3/zhangxin/wuwen/vila-1.5/our_eval/test_multiview.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=105'>106</a> '''
#     <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a224c4d32227d/data3/zhangxin/wuwen/vila-1.5/our_eval/test_multiview.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=106'>107</a> evaluation_metrics("/data3/zhangxin/wuwen/vila-1.5/rebuttal_results/pop/vila_train_all_sisv_pretrain_att_35w_clean_8bV4.jsonl")
# ...

# %%
evaluation_metrics("/data3/zhangxin/wuwen/vila-1.5/rebuttal_results/multi/depression/vila_train_all_sisv_pretrain_att_186w_clean_8B_llava_instruct150k.jsonl")

evaluation_metrics("/data3/zhangxin/wuwen/vila-1.5/rebuttal_results/multi/poverty_ratio/vila_train_all_sisv_pretrain_att_186w_clean_8B_llava_instruct150k.jsonl")
evaluation_metrics("/data3/zhangxin/wuwen/vila-1.5/rebuttal_results/multi/pop/vila_train_all_sisv_pretrain_att_186w_clean_8B_llava_instruct150k.jsonl")

evaluation_metrics("/data3/zhangxin/wuwen/vila-1.5/rebuttal_results/multi/income/vila_train_all_sisv_pretrain_att_186w_clean_8B_llava_instruct150k.jsonl")
evaluation_metrics("/data3/zhangxin/wuwen/vila-1.5/last_results/pop/vila_train_all_sisv_pretrain_att_186w_clean_8B_llava_instruct150k.jsonl")

evaluation_metrics("/data3/zhangxin/wuwen/vila-1.5/last_results/nightlight/vila_train_all_sisv_pretrain_att_186w_clean_8B_llava_instruct150k.jsonl")
# Out:
# 0.742
# 0.725
# 0.582
# 0.806
# 0.904
# 0.773

# %%
evaluation_metrics("/data3/zhangxin/wuwen/vila-1.5/last_results/pop/vila_train_all_sisv_pretrain_att_sharegpt4v_186w_clean_8B_llava_instruct150k.jsonl")
evaluation_metrics("/data3/zhangxin/wuwen/vila-1.5/last_results/nightlight/vila_train_all_sisv_pretrain_att_sharegpt4v_186w_clean_8B_llava_instruct150k.jsonl")
# Out:
# 0.907
# 0.761

# %%
evaluation_metrics("/data3/zhangxin/wuwen/vila-1.5/last_results/sv/PlacePulse_more_beautiful//vila_train_all_sisv_pretrain_att_186w_clean_8B_llava_instruct150k.jsonl")
evaluation_metrics("/data3/zhangxin/wuwen/vila-1.5/last_results/sv/PlacePulse_wealthier//vila_train_all_sisv_pretrain_att_186w_clean_8B_llava_instruct150k.jsonl")
evaluation_metrics("/data3/zhangxin/wuwen/vila-1.5/last_results/sv/PlacePulse_more_depressing/vila_train_all_sisv_pretrain_att_186w_clean_8B_llava_instruct150k.jsonl")
# Out:
# 0.835
# 0.779
# 0.746

# %%
evaluation_metrics("/data3/zhangxin/wuwen/vila-1.5/last_results/sv/PlacePulse_more_beautiful//vila_train_all_sisv_pretrain_att_sharegpt4v_186w_clean_8B_llava_instruct150k.jsonl")
evaluation_metrics("/data3/zhangxin/wuwen/vila-1.5/last_results/sv/PlacePulse_wealthier//vila_train_all_sisv_pretrain_att_sharegpt4v_186w_clean_8B_llava_instruct150k.jsonl")
evaluation_metrics("/data3/zhangxin/wuwen/vila-1.5/last_results/sv/PlacePulse_more_depressing/vila_train_all_sisv_pretrain_att_sharegpt4v_186w_clean_8B_llava_instruct150k.jsonl")
# Out:
# 0.836
# 0.787
# 0.758

# %%
evaluation_metrics("/data3/zhangxin/wuwen/vila-1.5/rebuttal_results/multi/depression/Llama-3-VILA1.5-8B.jsonl")
evaluation_metrics("/data3/zhangxin/wuwen/vila-1.5/rebuttal_results/multi/income/Llama-3-VILA1.5-8B.jsonl")
evaluation_metrics("/data3/zhangxin/wuwen/vila-1.5/rebuttal_results/multi/poverty_ratio/Llama-3-VILA1.5-8B.jsonl")
evaluation_metrics("/data3/zhangxin/wuwen/vila-1.5/rebuttal_results/multi/pop/Llama-3-VILA1.5-8B.jsonl")

evaluation_metrics("/data3/zhangxin/wuwen/vila-1.5/rebuttal_results/pop/Llama-3-VILA1.5-8B.jsonl")
evaluation_metrics("/data3/zhangxin/wuwen/vila-1.5/rebuttal_results/nightlight/Llama-3-VILA1.5-8B.jsonl")
# Out:
# 0.5223555070883316
# 0.6016859852476291
# 0.4967741935483871
# 0.5254424778761062
# 0.7096774193548387
# 0.45549738219895286

# %%
evaluation_metrics("/data3/zhangxin/wuwen/vila-1.5/last_results/multi/depression/vila_train_all_sisv_pretrain_att_sharegpt4v_186w_clean_8B_llava_instruct150k.jsonl")

evaluation_metrics("/data3/zhangxin/wuwen/vila-1.5/last_results/multi/income/vila_train_all_sisv_pretrain_att_sharegpt4v_186w_clean_8B_llava_instruct150k.jsonl")
evaluation_metrics("/data3/zhangxin/wuwen/vila-1.5/last_results/multi/pop/vila_train_all_sisv_pretrain_att_sharegpt4v_186w_clean_8B_llava_instruct150k.jsonl")
evaluation_metrics("/data3/zhangxin/wuwen/vila-1.5/last_results/multi/poverty_ratio/vila_train_all_sisv_pretrain_att_sharegpt4v_186w_clean_8B_llava_instruct150k.jsonl")
# Out:
# 0.761
# 0.796
# 0.567
# 0.731

# %%
evaluation_metrics("/data3/zhangxin/wuwen/vila-1.5/rebuttal_results/sv/PlacePulse_more_depressing/Llama-3-VILA1.5-8B.jsonl")
evaluation_metrics("/data3/zhangxin/wuwen/vila-1.5/rebuttal_results/sv/PlacePulse_more_beautiful/Llama-3-VILA1.5-8B.jsonl")
evaluation_metrics("/data3/zhangxin/wuwen/vila-1.5/rebuttal_results/sv/PlacePulse_wealthier/Llama-3-VILA1.5-8B.jsonl")
# Out:
# 0.309
# 0.46
# 0.666

# %%
evaluation_metrics("/data3/zhangxin/wuwen/rebuttal_results/sv/PlacePulse_more_beautiful/vila_train_all_sisv_pretrain_att_100w_clean_8b.jsonl")
evaluation_metrics("/data3/zhangxin/wuwen/rebuttal_results/sv/PlacePulse_wealthier/vila_train_all_sisv_pretrain_att_100w_clean_8b.jsonl")

evaluation_metrics("/data3/zhangxin/wuwen/rebuttal_results/sv/PlacePulse_more_depressing/vila_train_all_sisv_pretrain_att_100w_clean_8b.jsonl")
# Out:
# 0.875
# 0.7565217391304347
# 0.7933884297520661

# %%
evaluation_metrics("/data3/zhangxin/wuwen/vila-1.5/rebuttal_results/sv/PlacePulse_more_beautiful/vila_train_all_sisv_pretrain_att_35w_clean_8bV4.jsonl")

evaluation_metrics("/data3/zhangxin/wuwen/vila-1.5/rebuttal_results/sv/PlacePulse_wealthier/vila_train_all_sisv_pretrain_att_35w_clean_8bV4.jsonl")

evaluation_metrics("/data3/zhangxin/wuwen/vila-1.5/rebuttal_results/sv/PlacePulse_more_depressing/vila_train_all_sisv_pretrain_att_35w_clean_8bV4.jsonl")
# Out:
# 0.8846153846153846
# 0.808
# 0.7709923664122137

# %%
evaluation_metrics("/data3/zhangxin/wuwen/vila-1.5/rebuttal_results/multi/poverty_ratio/vila_train_all_sisv_pretrain_att_186w_clean_8B_multi2.jsonl")

evaluation_metrics("/data3/zhangxin/wuwen/vila-1.5/rebuttal_results/multi/poverty_ratio/vila_train_all_sisv_pretrain_att_186w_clean_8B_multi4.jsonl")
evaluation_metrics("/data3/zhangxin/wuwen/vila-1.5/rebuttal_results/multi/poverty_ratio/vila_train_all_sisv_pretrain_att_186w_clean_8B_multi6.jsonl")

evaluation_metrics("/data3/zhangxin/wuwen/vila-1.5/rebuttal_results/multi/depression/vila_train_all_sisv_pretrain_att_186w_clean_8B_multi2.jsonl")

evaluation_metrics("/data3/zhangxin/wuwen/vila-1.5/rebuttal_results/multi/depression/vila_train_all_sisv_pretrain_att_186w_clean_8B_multi4.jsonl")
evaluation_metrics("/data3/zhangxin/wuwen/vila-1.5/rebuttal_results/multi/depression/vila_train_all_sisv_pretrain_att_186w_clean_8B_multi6.jsonl")

evaluation_metrics("/data3/zhangxin/wuwen/vila-1.5/rebuttal_results/multi/pop/vila_train_all_sisv_pretrain_att_186w_clean_8B_multi2.jsonl")

evaluation_metrics("/data3/zhangxin/wuwen/vila-1.5/rebuttal_results/multi/pop/vila_train_all_sisv_pretrain_att_186w_clean_8B_multi4.jsonl")
evaluation_metrics("/data3/zhangxin/wuwen/vila-1.5/rebuttal_results/multi/pop/vila_train_all_sisv_pretrain_att_186w_clean_8B_multi6.jsonl")


evaluation_metrics("/data3/zhangxin/wuwen/vila-1.5/rebuttal_results/multi/income/vila_train_all_sisv_pretrain_att_186w_clean_8B_multi2.jsonl")

evaluation_metrics("/data3/zhangxin/wuwen/vila-1.5/rebuttal_results/multi/income/vila_train_all_sisv_pretrain_att_186w_clean_8B_multi4.jsonl")
evaluation_metrics("/data3/zhangxin/wuwen/vila-1.5/rebuttal_results/multi/income/vila_train_all_sisv_pretrain_att_186w_clean_8B_multi6.jsonl")
# Out:
# 0.6964618249534451
# 0.6890130353817505
# 0.7206703910614525
# 0.7243346007604563
# 0.7718631178707225
# 0.7642585551330798
# 0.5959409594095941
# 0.5959409594095941
# 0.6143911439114391
# 0.7660377358490567
# 0.7886792452830189
# 0.809433962264151

# %%
base = [json.loads(q) for q in open("/data3/maruolong/Train_Data/baseline/Qwen2-VL-72B/train_gini_coefficient.jsonl", "r")]

# %%
def evaluation_metrics_qwenvl(test_pred_jsonl):


    results = {}
    with open(test_pred_jsonl, "r") as f:
        test_pred_data = f.readlines()
        
        
    test_pred_list = []
    test_label_list = []

    # Calculate accuracy for Socioeconomic Prediction tasks
    for i in range(len(test_pred_data)):
        test_pred = ast.literal_eval(test_pred_data[i])["predict"]
        try:
            test_pred_list.append(np.floor(float(test_pred)))
            test_label = ast.literal_eval(test_pred_data[i])["label"]
            test_label_list.append(np.floor(float(test_label)))
        except:
            continue

    acc = compare(test_label_list, test_pred_list, margin=2)
    print(acc)
print(evaluation_metrics_qwenvl("/data3/maruolong/Train_Data/baseline/Qwen2-VL-72B/train_gini_coefficient.jsonl"))
# Out:
# 0.5007696254489482
# None

# %%
evaluation_metrics("/data3/zhangxin/wuwen/vila-1.5/rebuttal_results/multi/pop/vila_train_all_sisv_pretrain_att_186w_clean_8B_multi2.jsonl")

evaluation_metrics("/data3/zhangxin/wuwen/vila-1.5/rebuttal_results/multi/income/vila_train_all_sisv_pretrain_att_186w_clean_8B_multi2.jsonl")
evaluation_metrics("/data3/zhangxin/wuwen/vila-1.5/rebuttal_results/multi/poverty_ratio/vila_train_all_sisv_pretrain_att_186w_clean_8B_multi2.jsonl")
evaluation_metrics("/data3/zhangxin/wuwen/vila-1.5/rebuttal_results/multi/depression/vila_train_all_sisv_pretrain_att_186w_clean_8B_multi2.jsonl")
# Out:
# 0.5213675213675214
# 0.7916666666666666
# 0.7480314960629921
# 0.7258064516129032

# %%
evaluation_metrics("/mnt/public/vila-1.5/paper_results/multi/pop/vila_train_all_sisv_pretrain_att_186w_clean_3b.jsonl")
# Out:
# 0.5876288659793815

# %%
evaluation_metrics("/mnt/public/vila-1.5/paper_results/multi/pop/vila_train_all_sisv_att_186w_clean_13bV2.jsonl")
evaluation_metrics("/mnt/public/vila-1.5/paper_results/multi/income/vila_train_all_sisv_att_186w_clean_13bV2.jsonl")
#evaluation_metrics("/mnt/public/vila-1.5/paper_results/sv/PlacePulse_more_beautiful/vila_train_all_sisv_pretrain_att_186w_clean.jsonl")
evaluation_metrics("/mnt/public/vila-1.5/paper_results/multi/poverty_ratio/vila_train_all_sisv_att_186w_clean_13bV2.jsonl")
evaluation_metrics("/mnt/public/vila-1.5/paper_results/multi/depression/vila_train_all_sisv_att_186w_clean_13bV2.jsonl")
# Out:
# 0.5714285714285714
# 0.7978723404255319
# 0.7623762376237624
# 0.7142857142857143

# %%
evaluation_metrics("/mnt/public/vila-1.5/paper_results/multi/pop/vila_train_all_sisv_pretrain_186w_clean.jsonl")
evaluation_metrics("/mnt/public/vila-1.5/paper_results/multi/income/vila_train_all_sisv_pretrain_186w_clean.jsonl")
#evaluation_metrics("/mnt/public/vila-1.5/paper_results/sv/PlacePulse_more_beautiful/vila_train_all_sisv_pretrain_att_186w_clean.jsonl")
evaluation_metrics("/mnt/public/vila-1.5/paper_results/multi/poverty_ratio/vila_train_all_sisv_pretrain_186w_clean.jsonl")
evaluation_metrics("/mnt/public/vila-1.5/paper_results/multi/depression/vila_train_all_sisv_pretrain_186w_clean.jsonl")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /data3/zhangxin/wuwen/vila-1.5/our_eval/test_multiview.ipynb 单元格 10 line 1
# ----> <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a224c4d32227d/data3/zhangxin/wuwen/vila-1.5/our_eval/test_multiview.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> evaluation_metrics("/mnt/public/vila-1.5/paper_results/multi/pop/vila_train_all_sisv_pretrain_186w_clean.jsonl")
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a224c4d32227d/data3/zhangxin/wuwen/vila-1.5/our_eval/test_multiview.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> evaluation_metrics("/mnt/public/vila-1.5/paper_results/multi/income/vila_train_all_sisv_pretrain_186w_clean.jsonl")
# ...

# %%
evaluation_metrics("/mnt/public/vila-1.5/paper_results/sv/PlacePulse_more_beautiful/vila_train_all_sisv_att_186w_clean_13bV2.jsonl")
evaluation_metrics("/mnt/public/vila-1.5/paper_results/sv/PlacePulse_wealthier/vila_train_all_sisv_att_186w_clean_13bV2.jsonl")
evaluation_metrics("/mnt/public/vila-1.5/paper_results/sv/PlacePulse_more_depressing/vila_train_all_sisv_att_186w_clean_13bV2.jsonl")
# Out:
# 0.8636363636363636
# 0.7904761904761904
# 0.7927927927927928

# %%
evaluation_metrics("/mnt/public/vila-1.5/paper_results/sv/PlacePulse_more_beautiful/vila_train_all_sisv_clean_8b.jsonl")
evaluation_metrics("/mnt/public/vila-1.5/paper_results/sv/PlacePulse_more_beautiful/vila_train_all_sisv_pretrain_186w_clean_only_si.jsonl")

evaluation_metrics("/mnt/public/vila-1.5/paper_results/sv/PlacePulse_more_beautiful/vila_train_all_sisv_pretrain_186w_clean_only_sv.jsonl")
evaluation_metrics("/mnt/public/vila-1.5/paper_results/sv/PlacePulse_more_beautiful/vila_train_all_sisv_pretrain_186w_clean.jsonl")
# Out:
# 0.8775510204081632
# 0.8803418803418803
# 0.8974358974358975
# 0.7706422018348624

# %%
evaluation_metrics("/mnt/public/vila-1.5/paper_results/pop/vila_train_all_sisv_att_186w_clean_13bV2.jsonl")
evaluation_metrics("/mnt/public/vila-1.5/paper_results/nightlight/vila_train_all_sisv_att_186w_clean_13bV2.jsonl")
# Out:
# 0.8705882352941177
# 0.7282608695652174

# %%
evaluation_metrics("/mnt/public/vila-1.5/paper_results/pop/vila_train_all_sisv_pretrain_186w_clean_only_si.jsonl")
evaluation_metrics("/mnt/public/vila-1.5/paper_results/pop/vila_train_all_sisv_pretrain_186w_clean_only_sv.jsonl")
evaluation_metrics("/mnt/public/vila-1.5/paper_results/nightlight/vila_train_all_sisv_pretrain_186w_clean_only_si.jsonl")
evaluation_metrics("/mnt/public/vila-1.5/paper_results/nightlight/vila_train_all_sisv_pretrain_186w_clean_only_sv.jsonl")
# Out:
# 0.8804347826086957
# 0.9130434782608695
# 0.7070707070707071
# 0.7373737373737373

# %%
evaluation_metrics("/mnt/public/vila-1.5/paper_results/pop/vila_train_all_sisv_pretrain_186w_clean.jsonl")
evaluation_metrics("/mnt/public/vila-1.5/paper_results/nightlight/vila_train_all_sisv_pretrain_186w_clean.jsonl")
evaluation_metrics("/mnt/public/vila-1.5/paper_results/pop/vila_train_all_sisv_clean_8b.jsonl")
evaluation_metrics("/mnt/public/vila-1.5/paper_results/nightlight/vila_train_all_sisv_clean_8b.jsonl")
# Out:
# 0.8690476190476191
# 0.7472527472527473
# 0.863013698630137
# 0.7125

# %%
evaluation_metrics("/mnt/public/vila-1.5/paper_results/multi/pop/vila_train_all_sisv_clean_8b.jsonl")
evaluation_metrics("/mnt/public/vila-1.5/paper_results/multi/pop/vila_train_all_sisv_pretrain_186w_clean_only_si.jsonl")

evaluation_metrics("/mnt/public/vila-1.5/paper_results/multi/pop/vila_train_all_sisv_pretrain_186w_clean_only_sv.jsonl")
evaluation_metrics("/mnt/public/vila-1.5/paper_results/multi/pop/vila_train_all_sisv_pretrain_186w_clean.jsonl")
# Out:
# 0.5569620253164557
# 0.5306122448979592
# 0.5204081632653061
# 0.4777777777777778
